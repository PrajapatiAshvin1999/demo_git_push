# %%
print(Hello World)
# Out:
#   Cell In[1], line 1
#     print(Hello World)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('hello world')
# Out:
# hello world

# %%
print(3)
# Out:
# 3

# %%
print("")
